# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('/content/drive/MyDrive/HAR/UCI_HAR_dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# Getting the train data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('/content/drive/MyDrive/HAR/UCI_HAR_dataset/train/X_train.txt', delim_whitespace=True, header=None)
X_train.columns = [features]
# add subject column to the dataframe
X_train['subject'] = pd.read_csv('/content/drive/MyDrive/HAR/UCI_HAR_dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('/content/drive/MyDrive/HAR/UCI_HAR_dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample(2)
# Out:
#      tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 229           0.276828         -0.016123         -0.110234        -0.997309
# 3278          0.273579         -0.019343         -0.111183        -0.995041
#
#      tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 229         -0.986608        -0.988361        -0.997664        -0.986321
# 3278        -0.986261        -0.981550        -0.995708        -0.985683
#
#      tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 229         -0.988744        -0.941474  ...                    0.182174
# 3278        -0.981907        -0.938102  ...                    0.085051
#
#      angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 229                              0.016953                        -0.366925
# 3278                             0.049563                        -0.445270
#
#      angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 229                             -0.477960            -0.737303
# 3278                             0.391983            -0.585284
#
#      angle(Y,gravityMean) angle(Z,gravityMean) subject Activity ActivityName
# 229              0.010155            -0.149584       1        4      SITTING
# 3278             0.221781             0.284577      17        5     STANDING
#
# [2 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# Getting the train data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('/content/drive/MyDrive/HAR/UCI_HAR_dataset/test/X_test.txt', delim_whitespace=True, header=None)
X_test.columns = [features]
# add subject column to the dataframe
X_test['subject'] = pd.read_csv('/content/drive/MyDrive/HAR/UCI_HAR_dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('/content/drive/MyDrive/HAR/UCI_HAR_dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample(2)
# Out:
#      tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 2624          0.275353         -0.013110         -0.099995        -0.997319
# 2242          0.277722         -0.019074         -0.110082        -0.977739
#
#      tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 2624        -0.978539        -0.976186        -0.997520        -0.976527
# 2242        -0.813301        -0.931671        -0.982296        -0.812724
#
#      tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 2624        -0.979763        -0.942192  ...                    0.058762
# 2242        -0.927140        -0.900726  ...                   -0.082091
#
#      angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 2624                            -0.026376                        -0.487289
# 2242                             0.341117                         0.966884
#
#      angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 2624                             0.280335            -0.880721
# 2242                             0.976169            -0.832333
#
#      angle(Y,gravityMean) angle(Z,gravityMean) subject Activity ActivityName
# 2624             0.014283             0.038357      24        4      SITTING
# 2242             0.208318            -0.019620      20        5     STANDING
#
# [2 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# Time to Data Cleaning

# %% [markdown]
# 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2881: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# 3. Save this dataframe in a csv files

# %%
train.to_csv('/content/drive/MyDrive/HAR/UCI_HAR_dataset/csv_files/train.csv', index=False)
test.to_csv('/content/drive/MyDrive/HAR/UCI_HAR_dataset/csv_files/test.csv', index=False)

# %% [markdown]
# Exploratory Data Analysis

# %% [markdown]
# Obtain the train and test data

# %%
train = pd.read_csv('/content/drive/MyDrive/HAR/UCI_HAR_dataset/csv_files/train.csv')
test = pd.read_csv('/content/drive/MyDrive/HAR/UCI_HAR_dataset/csv_files/test.csv')
print(train.shape, test.shape)
# Out:
# (7352, 564) (2947, 564)

# %% [markdown]
# All the feature name with lots of unnecessary singhs: Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# 1. investigate participants activity durations.
# *Since the dataset has been created in a scientific environment nearly equal preconditions for the participants can be assumed. Let us investigate their activity durations.

# %%
import matplotlib as mlt
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# Nearly all participants have more data for walking upstairs than downstairs. Assuming an equal number of up- and down-walks the participants need longer walking upstairs.

# %% [markdown]
# How Are The ActivityName Distributed?

# %%
import plotly
import plotly.graph_objects as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot


# Plotting data
label_counts = train['ActivityName'].value_counts()

# Get colors
n = label_counts.shape[0]
colormap = plt.get_cmap('viridis')
colors = [mlt.colors.to_hex(colormap(col)) for col in np.arange(0, 1.01, 1/(n-1))]

# Create plot
data = go.Bar(x = label_counts.index,
              y = label_counts,
              marker = dict(color = colors))

layout = go.Layout(title = 'Smartphone ActivityName Distribution',
                   xaxis = dict(title = 'ActivityName'),
                   yaxis = dict(title = 'Count'))

fig = go.Figure(data=[data], layout=layout)
fig.show()
#iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7899ea0e-760f-4a29-8df6-68a8564cfc4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7899ea0e-760f-4a29-8df6-68a8564cfc4c")) {                    Plotly.newPlot(                        "7899ea0e-760f-4a29-8df6-68a8564cfc4c",                        [{"marker":{"color":["#440154","#414487","#2a788e","#22a884","#7ad151","#fde725"]},"x":["LAYING","STANDING","SITTING","WALKING","WALKING_UPSTAIRS","WALKING_DOWNSTAIRS"],"y":[1407,1374,1286,1226,1073,986],"type":"bar"}],                        {"title":{"text":"Smartphone ActivityName Distribution"},"xaxis":{"title":{"text":"ActivityName"}},"yaxis":{"title":{"text":"Count"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"color ...

# %% [markdown]
# Although there are fluctuations in the label counts, the labels are quite
# equally distributed.
#
# Assuming the participants had to walk the same number of stairs upwards as well as downwards and knowing the smartphones had a constant sampling rate, there should be the same amount of datapoints for walking upstairs and downstairs.
#
# Disregarding the possibility of flawed data, the participants seem to walk roughly 10% faster downwards.

# %% [markdown]
# 2. Featuring Engineering from Domain Knowledge
# Static and Dynamic Activities
#
# In static activities (sit, stand, lie down) motion information will not be very useful.
# In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.
# 3. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', height=5,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.960,12), xytext=(-0.5, 15), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).

# %% [markdown]
# As aspected from most real world data, when participants are moving the data is normally distributed with some long tail

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.08, -0.2, 0.1, 20])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).

# %% [markdown]
# We can see clearly here, the distribuation of Stationary Activities and Moving Activities.

# %% [markdown]
# 4. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# 5. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# If angleX,gravityMean > 0 then Activity is Laying.
# We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# Apply t-sne on the data
#
# Are The Activities Separable?
# The dataset is geared towards classifying the activity of the participant. Let us investigate the separability of the classes.

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, height=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.003s...
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 1.877s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.597443
# [t-SNE] Computed conditional probabilities in 0.052s
# [t-SNE] Iteration 50: error = 124.7423859, gradient norm = 0.0301636 (50 iterations in 3.549s)
# [t-SNE] Iteration 100: error = 106.7835617, gradient norm = 0.0296506 (50 iterations in 2.314s)
# [t-SNE] Iteration 150: error = 100.6090317, gradient norm = 0.0206656 (50 iterations in 1.943s)
# [t-SNE] Iteration 200: error = 97.2203369, gradient norm = 0.0157843 (50 iterations in 1.926s)
# [t-SNE] Iteration 250: error = 94.9176483, gradient norm = 0.0145279 (50 iterations in 1.893s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 94.917648
# [t-SNE] Iteration 300: error = 4.1137314, gradient norm = 0.0015611 (50 iterations in 1.846s)
# [t-SNE] Iteration 350: error = 3.2056923, gradient norm = 0.0010056 (50 iterations in 1.907s)
# [t-SNE] Iteration 400: error = 2.7753143, gradient norm = 0.0007154 (50 iterations in 1.968s)
# [t-SNE] Iteration 450: error = 2.5111523, gradient norm = 0.0005665 (50 iterations in 1.995s)
# [t-SNE] Iteration 500: error = 2.3280735, gradient norm = 0.0004749 (50 iterations in 2.071s)
# [t-SNE] Iteration 550: error = 2.1895885, gradient norm = 0.0004189 (50 iterations in 4.420s)
# [t-SNE] Iteration 600: error = 2.0802629, gradient norm = 0.0003717 (50 iterations in 1.980s)
# [t-SNE] Iteration 650: error = 1.9902878, gradient norm = 0.0003290 (50 iterations in 2.002s)
# [t-SNE] Iteration 700: error = 1.9146404, gradient norm = 0.0003020 (50 iterations in 2.035s)
# [t-SNE] Iteration 750: error = 1.8493109, gradient norm = 0.0002812 (50 iterations in 1.978s)
# [t-SNE] Iteration 800: error = 1.7926333, gradient norm = 0.0002545 (50 iterations in 2.011s)
# [t-SNE] Iteration 850: error = 1.7424982, gradient norm = 0.0002384 (50 iterations in 2.000s)
# [t-SNE] Iteration 900: error = 1.6976186, gradient norm = 0.0002219 (50 iterations in 3.274s)
# [t-SNE] Iteration 950: error = 1.6576679, gradient norm = 0.0002111 (50 iterations in 2.634s)
# [t-SNE] Iteration 1000: error = 1.6213956, gradient norm = 0.0001990 (50 iterations in 2.011s)
# [t-SNE] KL divergence after 1000 iterations: 1.621396
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.005s...
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 1.686s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961446
# [t-SNE] Computed conditional probabilities in 0.064s
# [t-SNE] Iteration 50: error = 113.9749603, gradient norm = 0.0218923 (50 iterations in 3.684s)
# [t-SNE] Iteration 100: error = 97.5452118, gradient norm = 0.0182952 (50 iterations in 2.418s)
# [t-SNE] Iteration 150: error = 92.9763794, gradient norm = 0.0102294 (50 iterations in 2.011s)
# [t-SNE] Iteration 200: error = 91.0163574, gradient norm = 0.0061253 (50 iterations in 2.008s)
# [t-SNE] Iteration 250: error = 89.8457336, gradient norm = 0.0055039 (50 iterations in 1.988s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.845734
# [t-SNE] Iteration 300: error = 3.5658827, gradient norm = 0.0014539 (50 iterations in 1.974s)
# [t-SNE] Iteration 350: error = 2.8096709, gradient norm = 0.0007495 (50 iterations in 1.957s)
# [t-SNE] Iteration 400: error = 2.4301634, gradient norm = 0.0005225 (50 iterations in 1.960s)
# [t-SNE] Iteration 450: error = 2.2134285, gradient norm = 0.0004038 (50 iterations in 1.971s)
# [t-SNE] Iteration 500: error = 2.0692048, gradient norm = 0.0003299 (50 iterations in 2.003s)
# [t-SNE] Iteration 550: error = 1.9641898, gradient norm = 0.0002847 (50 iterations in 2.008s)
# [t-SNE] Iteration 600: error = 1.8831036, gradient norm = 0.0002465 (50 iterations in 2.001s)
# [t-SNE] Iteration 650: error = 1.8179568, gradient norm = 0.0002181 (50 iterations in 1.994s)
# [t-SNE] Iteration 700: error = 1.7641890, gradient norm = 0.0001989 (50 iterations in 1.988s)
# [t-SNE] Iteration 750: error = 1.7189059, gradient norm = 0.0001813 (50 iterations in 2.008s)
# [t-SNE] Iteration 800: error = 1.6799395, gradient norm = 0.0001645 (50 iterations in 2.025s)
# [t-SNE] Iteration 850: error = 1.6458290, gradient norm = 0.0001531 (50 iterations in 2.023s)
# [t-SNE] Iteration 900: error = 1.6158618, gradient norm = 0.0001414 (50 iterations in 1.993s)
# [t-SNE] Iteration 950: error = 1.5895642, gradient norm = 0.0001331 (50 iterations in 2.019s)
# [t-SNE] Iteration 1000: error = 1.5657828, gradient norm = 0.0001255 (50 iterations in 2.006s)
# [t-SNE] KL divergence after 1000 iterations: 1.565783
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.004s...
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 1.682s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133827
# [t-SNE] Computed conditional probabilities in 0.118s
# [t-SNE] Iteration 50: error = 105.6282501, gradient norm = 0.0179241 (50 iterations in 3.435s)
# [t-SNE] Iteration 100: error = 90.9720459, gradient norm = 0.0123947 (50 iterations in 2.425s)
# [t-SNE] Iteration 150: error = 87.6476135, gradient norm = 0.0065381 (50 iterations in 2.128s)
# [t-SNE] Iteration 200: error = 86.2785721, gradient norm = 0.0043697 (50 iterations in 2.156s)
# [t-SNE] Iteration 250: error = 85.5065308, gradient norm = 0.0037285 (50 iterations in 2.140s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.506531
# [t-SNE] Iteration 300: error = 3.1351295, gradient norm = 0.0013838 (50 iterations in 2.074s)
# [t-SNE] Iteration 350: error = 2.4901400, gradient norm = 0.0006491 (50 iterations in 2.049s)
# [t-SNE] Iteration 400: error = 2.1701970, gradient norm = 0.0004232 (50 iterations in 2.049s)
# [t-SNE] Iteration 450: error = 1.9855461, gradient norm = 0.0003140 (50 iterations in 2.092s)
# [t-SNE] Iteration 500: error = 1.8670905, gradient norm = 0.0002537 (50 iterations in 2.079s)
# [t-SNE] Iteration 550: error = 1.7839541, gradient norm = 0.0002117 (50 iterations in 2.103s)
# [t-SNE] Iteration 600: error = 1.7215247, gradient norm = 0.0001824 (50 iterations in 2.079s)
# [t-SNE] Iteration 650: error = 1.6724386, gradient norm = 0.0001623 (50 iterations in 2.085s)
# [t-SNE] Iteration 700: error = 1.6327395, gradient norm = 0.0001433 (50 iterations in 2.113s)
# [t-SNE] Iteration 750: error = 1.5999861, gradient norm = 0.0001311 (50 iterations in 2.091s)
# [t-SNE] Iteration 800: error = 1.5722034, gradient norm = 0.0001200 (50 iterations in 2.099s)
# [t-SNE] Iteration 850: error = 1.5488114, gradient norm = 0.0001105 (50 iterations in 2.102s)
# [t-SNE] Iteration 900: error = 1.5287969, gradient norm = 0.0001027 (50 iterations in 2.118s)
# [t-SNE] Iteration 950: error = 1.5113488, gradient norm = 0.0000985 (50 iterations in 2.127s)
# [t-SNE] Iteration 1000: error = 1.4965135, gradient norm = 0.0000918 (50 iterations in 2.120s)
# [t-SNE] KL divergence after 1000 iterations: 1.496513
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.004s...
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 2.634s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274336
# [t-SNE] Computed conditional probabilities in 0.369s
# [t-SNE] Iteration 50: error = 97.6798553, gradient norm = 0.0175900 (50 iterations in 3.945s)
# [t-SNE] Iteration 100: error = 84.1963196, gradient norm = 0.0077409 (50 iterations in 2.672s)
# [t-SNE] Iteration 150: error = 81.9895325, gradient norm = 0.0033716 (50 iterations in 2.602s)
# [t-SNE] Iteration 200: error = 81.1852951, gradient norm = 0.0025212 (50 iterations in 2.499s)
# [t-SNE] Iteration 250: error = 80.7823486, gradient norm = 0.0018367 (50 iterations in 2.463s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.782349
# [t-SNE] Iteration 300: error = 2.6992927, gradient norm = 0.0013115 (50 iterations in 2.408s)
# [t-SNE] Iteration 350: error = 2.1635995, gradient norm = 0.0005752 (50 iterations in 2.264s)
# [t-SNE] Iteration 400: error = 1.9130425, gradient norm = 0.0003495 (50 iterations in 2.260s)
# [t-SNE] Iteration 450: error = 1.7666639, gradient norm = 0.0002474 (50 iterations in 2.270s)
# [t-SNE] Iteration 500: error = 1.6728489, gradient norm = 0.0001930 (50 iterations in 2.320s)
# [t-SNE] Iteration 550: error = 1.6086010, gradient norm = 0.0001566 (50 iterations in 2.287s)
# [t-SNE] Iteration 600: error = 1.5621331, gradient norm = 0.0001347 (50 iterations in 2.299s)
# [t-SNE] Iteration 650: error = 1.5270655, gradient norm = 0.0001209 (50 iterations in 2.331s)
# [t-SNE] Iteration 700: error = 1.4998538, gradient norm = 0.0001078 (50 iterations in 2.305s)
# [t-SNE] Iteration 750: error = 1.4784887, gradient norm = 0.0000972 (50 iterations in 2.344s)
# [t-SNE] Iteration 800: error = 1.4611936, gradient norm = 0.0000907 (50 iterations in 2.307s)
# [t-SNE] Iteration 850: error = 1.4466996, gradient norm = 0.0000824 (50 iterations in 2.329s)
# [t-SNE] Iteration 900: error = 1.4340874, gradient norm = 0.0000795 (50 iterations in 2.337s)
# [t-SNE] Iteration 950: error = 1.4237123, gradient norm = 0.0000740 (50 iterations in 2.324s)
# [t-SNE] Iteration 1000: error = 1.4146519, gradient norm = 0.0000703 (50 iterations in 2.312s)
# [t-SNE] KL divergence after 1000 iterations: 1.414652
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.004s...
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 1.782s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.556s
# [t-SNE] Iteration 50: error = 87.3741989, gradient norm = 0.0036415 (50 iterations in 4.184s)
# [t-SNE] Iteration 100: error = 76.0872498, gradient norm = 0.0061348 (50 iterations in 4.774s)
# [t-SNE] Iteration 150: error = 74.8179169, gradient norm = 0.0025567 (50 iterations in 3.859s)
# [t-SNE] Iteration 200: error = 74.3689728, gradient norm = 0.0014554 (50 iterations in 3.870s)
# [t-SNE] Iteration 250: error = 74.1600571, gradient norm = 0.0013211 (50 iterations in 3.841s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.160057
# [t-SNE] Iteration 300: error = 2.1587803, gradient norm = 0.0011821 (50 iterations in 3.271s)
# [t-SNE] Iteration 350: error = 1.7635351, gradient norm = 0.0004895 (50 iterations in 2.964s)
# [t-SNE] Iteration 400: error = 1.5946122, gradient norm = 0.0002835 (50 iterations in 2.937s)
# [t-SNE] Iteration 450: error = 1.5002210, gradient norm = 0.0001902 (50 iterations in 2.944s)
# [t-SNE] Iteration 500: error = 1.4398186, gradient norm = 0.0001429 (50 iterations in 2.994s)
# [t-SNE] Iteration 550: error = 1.3983393, gradient norm = 0.0001122 (50 iterations in 2.998s)
# [t-SNE] Iteration 600: error = 1.3683782, gradient norm = 0.0000945 (50 iterations in 3.008s)
# [t-SNE] Iteration 650: error = 1.3462789, gradient norm = 0.0000815 (50 iterations in 3.028s)
# [t-SNE] Iteration 700: error = 1.3302945, gradient norm = 0.0000740 (50 iterations in 3.063s)
# [t-SNE] Iteration 750: error = 1.3187016, gradient norm = 0.0000694 (50 iterations in 3.032s)
# [t-SNE] Iteration 800: error = 1.3099439, gradient norm = 0.0000636 (50 iterations in 3.027s)
# [t-SNE] Iteration 850: error = 1.3030304, gradient norm = 0.0000573 (50 iterations in 3.096s)
# [t-SNE] Iteration 900: error = 1.2969452, gradient norm = 0.0000556 (50 iterations in 3.059s)
# [t-SNE] Iteration 950: error = 1.2921283, gradient norm = 0.0000532 (50 iterations in 5.418s)
# [t-SNE] Iteration 1000: error = 1.2879744, gradient norm = 0.0000533 (50 iterations in 3.137s)
# [t-SNE] KL divergence after 1000 iterations: 1.287974
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
